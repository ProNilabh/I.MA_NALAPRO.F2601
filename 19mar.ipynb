# %%
import torch
import numpy as np

# %%
data = [[1,2],[3,4]]

# %%
tensor_1 = torch.tensor(data)

# %%
type(tensor_1)
# Out:
# torch.Tensor

# %%
np_array = np.array(data)
tensor_2 = torch.from_numpy(np_array)

# %%
if torch.cuda.is_available():
    print("CUDA is there")

# %%
if torch.cuda.is_available():
    print("CUDA is there")
else:
    print("haha")
# Out:
# haha

# %%
tensor_mul = torch.ones_like(tensor_2)

# %%
print(tensor_mul)
# Out:
# tensor([[1, 1],
#         [1, 1]])
